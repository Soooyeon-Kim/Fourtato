# %%
import pandas as pd
import numpy as np

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %%
import matplotlib.pyplot as plt
yf.pdr_override()

# %%
pulmuone = pdr.get_data_yahoo('017810.KS',start='2021-01-01')
ottogi = pdr.get_data_yahoo('007310.KS',start='2016-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
pulmuone.head()
# Out:
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 2021-01-04  17000.0  17550.0  16650.0  17550.0    17550.0  374405
# 2021-01-05  17550.0  18750.0  17250.0  18650.0    18650.0  766196
# 2021-01-06  18750.0  18950.0  18000.0  18200.0    18200.0  297722
# 2021-01-07  18250.0  18300.0  17650.0  18000.0    18000.0  432063
# 2021-01-08  18700.0  19100.0  18300.0  18350.0    18350.0  636667

# %%
ottogi.loc['2019']
#df = df.sort_values(by='날짜')
# Out:
#                 Open      High       Low     Close    Adj Close  Volume
# Date
# 2019-01-02  717000.0  731000.0  708000.0  716000.0  696665.1875    2520
# 2019-01-03  721000.0  728000.0  714000.0  726000.0  706395.1250    3007
# 2019-01-04  731000.0  770000.0  723000.0  768000.0  747261.0000    9335
# 2019-01-07  777000.0  777000.0  753000.0  760000.0  739477.0625    4564
# 2019-01-08  763000.0  782000.0  753000.0  776000.0  755044.9375    6109
# ...              ...       ...       ...       ...          ...     ...
# 2019-12-23  547000.0  555000.0  545000.0  555000.0  540012.8125    4473
# 2019-12-24  551000.0  558000.0  547000.0  549000.0  534174.8125    3817
# 2019-12-26  553000.0  555000.0  549000.0  555000.0  540012.8125    1777
# 2019-12-27  546000.0  560000.0  541000.0  558000.0  550369.2500    3315
# 2019-12-30  562000.0  563000.0  554000.0  554000.0  546423.9375    2506
#
# [245 rows x 6 columns]

# %%
# subset 생성
pulmuone_High= pulmuone['High']
pulmuone_High
# Out:
# Date
# 2021-01-04    17550.0
# 2021-01-05    18750.0
# 2021-01-06    18950.0
# 2021-01-07    18300.0
# 2021-01-08    19100.0
#                ...
# 2021-05-07    18350.0
# 2021-05-10    19300.0
# 2021-05-11    21500.0
# 2021-05-12    21900.0
# 2021-05-13    23950.0
# Name: High, Length: 90, dtype: float64

# %%
ottogi['Close'].plot(title = 'Trend line of High column')
# Out:
# <AxesSubplot:title={'center':'Trend line of High column'}, xlabel='Date'>

# %%
ottogi_HL['High'].plot(label='High')
ottogi_HL['Low'].plot(label='Low')
plt.xlabel('date')
plt.ylabel('price')
plt.title('High and Low')
plt.legend()
plt.show()

# %%
pulmuone_Close = pulmuone['Close']

# %%
ottogi_2020 = ottogi_Close['2020']
ottogi_2020
# Out:
# Date
# 2020-01-02    549000.0
# 2020-01-03    548000.0
# 2020-01-06    538000.0
# 2020-01-07    540000.0
# 2020-01-08    525000.0
#                 ...
# 2020-12-23    574000.0
# 2020-12-24    578000.0
# 2020-12-28    585000.0
# 2020-12-29    574000.0
# 2020-12-30    577000.0
# Name: Close, Length: 248, dtype: float64

# %%
pulmuone_Close.loc['2017'].plot(label='2017')
pulmuone_Close.loc['2018'].plot(label='2018')
pulmuone_Close.loc['2019'].plot(label='2019')
pulmuone_Close.loc['2020'].plot(label='2020')
pulmuone_Close.loc['2021'].plot(label='2021')
plt.legend()

# %%
ottogi_HL['High'].loc['2017'].plot(label='high')
ottogi_Close.loc['2017'].plot(label='2017')
plt.legend()

# %%
ottogi_Close.loc['2017-05'].plot(label='5')
ottogi_Close.loc['2017-06'].plot(label='6')
ottogi_Close.loc['2017-07'].plot(label='7')
plt.legend()

# %%
ottogi['Close'].loc['2020-03'].plot(label='03')
ottogi['Close'].loc['2020-04'].plot(label='04')
ottogi['Close'].loc['2020-05'].plot(label='05')
plt.legend()

# %%
#2021
pulmuone['Close'].loc['2021-01'].plot(label='1')
pulmuone['Close'].loc['2021-02'].plot(label='2')
pulmuone['Close'].loc['2021-03'].plot(label='3')
pulmuone['Close'].loc['2021-04'].plot(label='4')
pulmuone['Close'].loc['2021-05'].plot(label='5')
#plt.legend()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#2018
ottogi['Close'].loc['2018-01'].plot(label='1')
ottogi['Close'].loc['2018-02'].plot(label='2')
ottogi['Close'].loc['2018-03'].plot(label='3')
ottogi['Close'].loc['2018-04'].plot(label='4')
ottogi['Close'].loc['2018-05'].plot(label='5')
ottogi['Close'].loc['2018-06'].plot(label='6')
ottogi['Close'].loc['2018-07'].plot(label='7')
ottogi['Close'].loc['2018-08'].plot(label='8')
ottogi['Close'].loc['2018-09'].plot(label='9')
ottogi['Close'].loc['2018-10'].plot(label='10')
ottogi['Close'].loc['2018-11'].plot(label='11')
ottogi['Close'].loc['2018-12'].plot(label='12')
#plt.legend()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ottogi['Close'].loc['2018-03']
# Out:
# Date
# 2018-03-02    698000.0
# 2018-03-05    696000.0
# 2018-03-06    695000.0
# 2018-03-07    691000.0
# 2018-03-08    738000.0
# 2018-03-09    735000.0
# 2018-03-12    733000.0
# 2018-03-13    725000.0
# 2018-03-14    723000.0
# 2018-03-15    733000.0
# 2018-03-16    727000.0
# 2018-03-19    723000.0
# 2018-03-20    722000.0
# 2018-03-21    723000.0
# 2018-03-22    727000.0
# 2018-03-23    704000.0
# 2018-03-26    711000.0
# 2018-03-27    708000.0
# 2018-03-28    712000.0
# 2018-03-29    711000.0
# 2018-03-30    712000.0
# Name: Close, dtype: float64

# %%
#2019
ottogi['Close'].loc['2019-01'].plot(label='1')
ottogi['Close'].loc['2019-02'].plot(label='2')
ottogi['Close'].loc['2019-03'].plot(label='3')
ottogi['Close'].loc['2019-04'].plot(label='4')
ottogi['Close'].loc['2019-05'].plot(label='5')
ottogi['Close'].loc['2019-06'].plot(label='6')
ottogi['Close'].loc['2019-07'].plot(label='7')
ottogi['Close'].loc['2019-08'].plot(label='8')
ottogi['Close'].loc['2019-09'].plot(label='9')
ottogi['Close'].loc['2019-10'].plot(label='10')
ottogi['Close'].loc['2019-11'].plot(label='11')
ottogi['Close'].loc['2019-12'].plot(label='12')
#plt.legend()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#2020
ottogi['Close'].loc['2020-01'].plot(label='1')
ottogi['Close'].loc['2020-02'].plot(label='2')
ottogi['Close'].loc['2020-03'].plot(label='3')
ottogi['Close'].loc['2020-04'].plot(label='4')
ottogi['Close'].loc['2020-05'].plot(label='5')
ottogi['Close'].loc['2020-06'].plot(label='6')
ottogi['Close'].loc['2020-07'].plot(label='7')
ottogi['Close'].loc['2020-08'].plot(label='8')
ottogi['Close'].loc['2020-09'].plot(label='9')
ottogi['Close'].loc['2020-10'].plot(label='10')
ottogi['Close'].loc['2020-11'].plot(label='11')
ottogi['Close'].loc['2020-12'].plot(label='12')
#plt.legend()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#2020
ottogi['Close'].loc['2020-01'].plot(label='1')
ottogi['Close'].loc['2020-02'].plot(label='2')
ottogi['Close'].loc['2020-03'].plot(label='3')

# %%
#2021
ottogi['Close'].loc['2021-01'].plot(label='1')
ottogi['Close'].loc['2021-02'].plot(label='2')
ottogi['Close'].loc['2021-03'].plot(label='3')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#남양 3월 거래량

ratio = [20932,15474,10028,49503,18419]
labels = ['2017-03', '2018-03', '2019-03', '2020-03','2021-03']
explode = [0.10, 0, 0, 0.10,0]
plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.title("Namyang_3")
plt.show()

# %%
namyang['거래량'].loc['2021-01'].sum()
# Out:
# 76366

# %%
#남양 2월 거래량

ratio = [10923,18369,11338,31889,45307]
labels = ['2017-02', '2018-02', '2019-02', '2020-02','2021-02']
explode = [0, 0, 0, 0.10,0.10]
plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.title("Namyang_2")
plt.show()

# %%
# 남양 1월 거래량

ratio = [9766,18715,14766,15947,76366]
labels = ['2017-01', '2018-01', '2019-01', '2020-01','2021-01']
explode = [0, 0.10, 0, 0,0.10]
plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.title("Namyang_1")
plt.show()

# %%
namyang['고가'].loc['2021-01'].plot(label="High")
namyang['저가'].loc['2021-01'].plot(label="Low")
namyang['종가'].loc['2021-01'].plot(label="Close")
plt.legend()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
#남양 1월 종가 그림
namyang['종가'].loc['2021-01'].plot(label="2021")
namyang['종가'].loc['2020-01'].plot(label="2020")
namyang['종가'].loc['2019-01'].plot(label="2019")
namyang['종가'].loc['2018-01'].plot(label="2018")
namyang['종가'].loc['2017-01'].plot(label="2017")
plt.legend()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
#남양 평균 금액
namyang_1_mean = []
namyang_1_mean.append((namyang['종가'].loc["2021-01"].sum())/namyang['종가'].loc["2021-01"].count())

# %%
namyang_1_mean
# Out:
# [297075.0]

# %%
namyang_1_mean.append((namyang['종가'].loc["2020-01"].sum())/namyang['종가'].loc["2020-01"].count())
namyang_1_mean.append((namyang['종가'].loc["2019-01"].sum())/namyang['종가'].loc["2019-01"].count())
namyang_1_mean.append((namyang['종가'].loc["2018-01"].sum())/namyang['종가'].loc["2021-01"].count())
namyang_1_mean.append((namyang['종가'].loc["2017-01"].sum())/namyang['종가'].loc["2021-01"].count())

# %%
namyang_2_mean = []
namyang_2_mean.append((namyang['종가'].loc["2021-02"].sum())/namyang['종가'].loc["2021-02"].count())
namyang_2_mean.append((namyang['종가'].loc["2017-02"].sum())/namyang['종가'].loc["2020-02"].count())
namyang_2_mean.append((namyang['종가'].loc["2019-02"].sum())/namyang['종가'].loc["2019-02"].count())
namyang_2_mean.append((namyang['종가'].loc["2018-02"].sum())/namyang['종가'].loc["2018-01"].count())
namyang_2_mean.append((namyang['종가'].loc["2017-02"].sum())/namyang['종가'].loc["2017-01"].count())

# %%
namyang_2_mean
# Out:
# [297805.55555555556, 740050.0, 628882.3529411765, 571818.1818181818, 740050.0]

# %%
#남양 1월 종가 평균
ratio = [297075.0,420025.0,627272.7272727273, 760700.0,731100.0]
labels = ['2021-01','2020-01', '2019-01', '2018-01','2017-01']
explode = [0, 0.10, 0, 0,0.10]
plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.title("Namyang_1_mean")
plt.show()

# %%
#남양 2월 종가 평균
ratio = [297805.55555555556, 740050.0, 628882.3529411765, 571818.1818181818,740050.0]
labels = ['2021-02','2020-02', '2019-02', '2018-02','2017-02']
explode = [0, 0.10, 0, 0,0.10]
plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.title("Namyang_1_mean")
plt.show()

# %% [markdown]
# ## 오뚜기

# %%
#index 를 날짜로 지정하면 연단위, 월단위, 일단위 조회 가능
ottogi = ottogi.set_index('날짜')
ottogi.head()
# Out:
#                 종가   전일비      시가      고가      저가   거래량
# 날짜
# 2021-03-22  583000  3000  586000  587000  579000  3963
# 2021-03-19  586000  2000  579000  586000  575000  5922
# 2021-03-18  584000  2000  586000  590000  582000  4070
# 2021-03-17  586000  3000  582000  587000  580000  3812
# 2021-03-16  583000  3000  580000  587000  578000  5291

# %%
#2017
ottogi['종가'].loc['2017-01'].plot(label='1')
ottogi['종가'].loc['2017-02'].plot(label='2')
ottogi['종가'].loc['2017-03'].plot(label='3')
ottogi['종가'].loc['2017-04'].plot(label='4')
ottogi['종가'].loc['2017-05'].plot(label='5')
ottogi['종가'].loc['2017-06'].plot(label='6')
ottogi['종가'].loc['2017-07'].plot(label='7')
ottogi['종가'].loc['2017-08'].plot(label='8')
ottogi['종가'].loc['2017-09'].plot(label='9')
ottogi['종가'].loc['2017-10'].plot(label='10')
ottogi['종가'].loc['2017-11'].plot(label='11')
ottogi['종가'].loc['2017-12'].plot(label='12')
# Out:
# <AxesSubplot:xlabel='날짜'>
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
#2018
ottogi['종가'].loc['2018-01'].plot(label='1')
ottogi['종가'].loc['2018-02'].plot(label='2')
ottogi['종가'].loc['2018-03'].plot(label='3')
ottogi['종가'].loc['2018-04'].plot(label='4')
ottogi['종가'].loc['2018-05'].plot(label='5')
ottogi['종가'].loc['2018-06'].plot(label='6')
ottogi['종가'].loc['2018-07'].plot(label='7')
ottogi['종가'].loc['2018-08'].plot(label='8')
ottogi['종가'].loc['2018-09'].plot(label='9')
ottogi['종가'].loc['2018-10'].plot(label='10')
ottogi['종가'].loc['2018-11'].plot(label='11')
ottogi['종가'].loc['2018-12'].plot(label='12')
# Out:
# <AxesSubplot:xlabel='날짜'>
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
#2019
ottogi['종가'].loc['2019-01'].plot(label='1')
ottogi['종가'].loc['2019-02'].plot(label='2')
ottogi['종가'].loc['2019-03'].plot(label='3')
ottogi['종가'].loc['2019-04'].plot(label='4')
ottogi['종가'].loc['2019-05'].plot(label='5')
ottogi['종가'].loc['2019-06'].plot(label='6')
ottogi['종가'].loc['2019-07'].plot(label='7')
ottogi['종가'].loc['2019-08'].plot(label='8')
ottogi['종가'].loc['2019-09'].plot(label='9')
ottogi['종가'].loc['2019-10'].plot(label='10')
ottogi['종가'].loc['2019-11'].plot(label='11')
ottogi['종가'].loc['2019-12'].plot(label='12')
# Out:
# <AxesSubplot:xlabel='날짜'>
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
#2020
ottogi['종가'].loc['2020-01'].plot(label='1')
ottogi['종가'].loc['2020-02'].plot(label='2')
ottogi['종가'].loc['2020-03'].plot(label='3')
ottogi['종가'].loc['2020-04'].plot(label='4')
ottogi['종가'].loc['2020-05'].plot(label='5')
ottogi['종가'].loc['2020-06'].plot(label='6')
ottogi['종가'].loc['2020-07'].plot(label='7')
ottogi['종가'].loc['2020-08'].plot(label='8')
ottogi['종가'].loc['2020-09'].plot(label='9')
ottogi['종가'].loc['2020-10'].plot(label='10')
ottogi['종가'].loc['2020-11'].plot(label='11')
ottogi['종가'].loc['2020-12'].plot(label='12')
# Out:
# <AxesSubplot:xlabel='날짜'>
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
#2021
ottogi['종가'].loc['2021-01'].plot(label='1')
ottogi['종가'].loc['2021-02'].plot(label='2')
ottogi['종가'].loc['2021-03'].plot(label='3')
# Out:
# <AxesSubplot:xlabel='날짜'>
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
